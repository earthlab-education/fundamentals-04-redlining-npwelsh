# %% [markdown]
# # STEP 1: Set up your analysis
#
# <link rel="stylesheet" type="text/css" href="./assets/styles.css"><div class="callout callout-style-default callout-titled callout-task"><div class="callout-header"><div class="callout-icon-container"><i class="callout-icon"></i></div><div class="callout-title-container flex-fill">Try It: Import packages</div></div><div class="callout-body-container callout-body"><p>Add imports for packages that help you:</p>
# <ol type="1">
# <li>Work with the file system interoperably</li>
# <li>Work with vector data</li>
# <li>Create interactive plots of vector data</li>
# </ol></div></div>

# %%
# Interoperable file paths
import os

# Find the home folder
import pathlib

# Work with vector data
import pandas as pd
import geopandas as gpd

# Interactive plots of vector data
import hvplot.pandas
import geoviews as gvdsfsad
# Out:
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='p1002'>
#   <div id="a5ec2fdb-5855-4069-bdef-ec77aa255581" data-root-id="p1002" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"916ffdc8-f259-4c77-999c-c6a011a4aa16":{"version":"3.5.2","title":"Bokeh Application","roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"p1002"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"p1003","attributes":{"plot_id":"p1002","comm_id":"e57768a98b254ec3a9e75a9cd87464f9","client_comm_id":"a984761f79834095b6fe1098e535c09f"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"gap","kind":"Any","default":""},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"mode","kind":"Any","default":"warn"},{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationAreaBase1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"notification_type","kind":"Any","default":null},{"name":"_destroyed","kind":"Any","default":false}]},{"type":"model","name":"TemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"BootstrapTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"TemplateEditor1","properties":[{"name":"layout","kind":"Any","default":[]}]},{"type":"model","name":"MaterialTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"ReactiveESM1"},{"type":"model","name":"JSComponent1"},{"ty ...
#   var render_items = [{"docid":"916ffdc8-f259-4c77-999c-c6a011a4aa16","roots":{"p1002":"a5ec2fdb-5855-4069-bdef-ec77aa255581"},"root_ids":["p1002"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   async function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     await Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && id_el.children[0].hasAttribute('data-root-id')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	  for (const child of root_el.children) {
#             // Ensure JupyterLab does not capture keyboard shortcuts
#             // see: https://jupyterlab.readthedocs.io/en/4.1.x/extension/notebook.html#keyboard-interaction-model
# 	    child.setAttribute('data-lm-suppress-shortcuts', 'true')
# 	  }
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined)
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>

# %% [markdown]
# <link rel="stylesheet" type="text/css" href="./assets/styles.css"><div class="callout callout-style-default callout-titled callout-task"><div class="callout-header"><div class="callout-icon-container"><i class="callout-icon"></i></div><div class="callout-title-container flex-fill">Try It: Prepare data directory</div></div><div class="callout-body-container callout-body"><p>In the cell below, <strong>reproducibly and interoperably</strong>
# define and create a project data directory somewhere in your home
# folder. Be careful not to save data files to your <code>git</code>
# repository!</p></div></div>

# %%
# Define and create the project data directory
redline_data_dir = os.path.join(
    pathlib.Path.home(), 
    'earth-analytics'
    'data',
    'redlining-project-directory-Nolan-Welsh'
)
os.makedirs(redline_data_dir, exist_ok=True)
redline_data_dir
# Out:
# 'C:\\Users\\Nolan Welsh\\earth-analyticsdata\\redlining-project-directory-Nolan-Welsh'

# %% [markdown]
# ## STEP 2: Site map
#
# <link rel="stylesheet" type="text/css" href="./assets/styles.css"><div class="callout callout-style-default callout-titled callout-task"><div class="callout-header"><div class="callout-icon-container"><i class="callout-icon"></i></div><div class="callout-title-container flex-fill">Try It: Define your study area</div></div><div class="callout-body-container callout-body"><ol type="1">
# <li>Copy the <strong>geopackage</strong> URL for the <a
# href="https://dsl.richmond.edu/panorama/redlining/data">University of
# Richmond</a></li>
# <li>Load the <em>vector</em> data into Python, making sure to cache the
# download so you don’t have to run it multiple times.</li>
# <li>Create a quick plot to check the data</li>
# </ol></div></div>

# %%
# Define info for redlining download
redline_shp_url = "https://dsl.richmond.edu/panorama/redlining/static/mappinginequality.gpkg"
redline_shp_dir = os.path.join(redline_data_dir,'UofRichmond_Redlining_data')
os.makedirs(redline_data_dir, exist_ok=True)
redline_data_path= os.path.join(redline_data_dir, 'redline_data.shp')

# Only download once
if not os.path.exists(redline_data_path):
    red_gdf = gpd.read_file(redline_shp_url)
    red_gdf.to_file(redline_data_path)
# Load from file
gdf_redline = gpd.read_file(redline_data_path)
# Check the data
gdf_redline.plot()
# Out:
# <Axes: >

# %%
# %store gdf_redline redline_data_dir
# Out:
# Stored 'gdf_redline' (GeoDataFrame)
# Stored 'redline_data_dir' (str)

# %% [markdown]
# <link rel="stylesheet" type="text/css" href="./assets/styles.css"><div class="callout callout-style-default callout-titled callout-task"><div class="callout-header"><div class="callout-icon-container"><i class="callout-icon"></i></div><div class="callout-title-container flex-fill">Try It: Create an interactive site map</div></div><div class="callout-body-container callout-body"><p>In the cell below:</p>
# <ol type="1">
# <li>Select only the data where the <code>city</code> column is equal to
# <code>"Denver"</code>.</li>
# <li>For now, dissolve the regions with the <code>.dissolve()</code>
# method so we see only a map of Denver.</li>
# <li>Plot the data with the <code>EsriImagery</code> tile source basemap.
# Make sure we can see your basemap underneath!</li>
# </ol></div></div>
#
# <link rel="stylesheet" type="text/css" href="./assets/styles.css"><div class="callout callout-style-default callout-titled callout-respond"><div class="callout-header"><div class="callout-icon-container"><i class="callout-icon"></i></div><div class="callout-title-container flex-fill">Reflect and Respond: Write a site description</div></div><div class="callout-body-container callout-body"><p>Your site description should address:</p>
# <ol type="1">
# <li>Is there anything relevant to this analysis that you notice in your
# site map?</li>
# <li>Research about the <strong>context</strong> of this analysis. You
# could include information about the climate and history of the Denver
# area. How might racism, water rights, or other societal forces have
# influenced the distribution of urban green space in Denver? Aim for a
# paragraph of text.</li>
# <li>Citations for the site data and your context sources.</li>
# </ol></div></div>

# %%
gdf_redline
# Out:
#        area_id        city state  city_surve         category grade label  \
# 0          244  Birmingham    AL        True             Best     A    A1
# 1          193  Birmingham    AL        True             Best     A    A2
# 2          206  Birmingham    AL        True             Best     A    A3
# 3          203  Birmingham    AL        True  Still Desirable     B    B1
# 4          189  Birmingham    AL        True  Still Desirable     B   B10
# ...        ...         ...   ...         ...              ...   ...   ...
# 10149     6518    Wheeling    WV        True        Hazardous     D    D4
# 10150     6520    Wheeling    WV        True        Hazardous     D    D5
# 10151     6516    Wheeling    WV        True        Hazardous     D    D6
# 10152     6512    Wheeling    WV        True        Hazardous     D    D7
# 10153     6513    Wheeling    WV        True        Hazardous     D    D8
#
#        residentia  commercial  industrial     fill  \
# 0            True       False       False  #76a865
# 1            True       False       False  #76a865
# 2            True       False       False  #76a865
# 3            True       False       False  #7cb5bd
# 4            True       False       False  #7cb5bd
# ...           ...         ...         ...      ...
# 10149        True       False       False  #d9838d
# 10150        True       False       False  #d9838d
# 10151        True       False       False  #d9838d
# 10152        True       False       False  #d9838d
# 10153        True       False       False  #d9838d
#
#                                                 geometry
# 0      POLYGON ((-86.75678 33.49754, -86.75692 33.495...
# 1      POLYGON ((-86.75867 33.50933, -86.76093 33.508...
# 2      POLYGON ((-86.75678 33.49754, -86.75196 33.501...
# 3      POLYGON ((-86.80111 33.48071, -86.80099 33.480...
# 4      POLYGON ((-86.74923 33.53333, -86.74916 33.530...
# ...                                                  ...
# 10149  POLYGON ((-80.71985 40.06376, -80.71789 40.063...
# 10150  POLYGON ((-80.72854 40.06729, -80.72837 40.065...
# 10151  POLYGON ((-80.72216 40.06134, -80.72256 40.060...
# 10152  POLYGON ((-80.64740 40.04886, -80.64845 40.048...
# 10153  POLYGON ((-80.66614 40.04970, -80.66395 40.047...
#
# [10154 rows x 12 columns]

# %%
denver_redlining_gdf = gdf_redline[gdf_redline.city=='Denver']

denver_redlining_gdf
# Out:
#       area_id    city state  city_surve              category grade  \
# 1103     6525  Denver    CO        True                  Best     A
# 1104     6529  Denver    CO        True                  Best     A
# 1105     6537  Denver    CO        True                  Best     A
# 1106     6536  Denver    CO        True                  Best     A
# 1107     6540  Denver    CO        True                  Best     A
# 1108     6550  Denver    CO        True                  Best     A
# 1109     6526  Denver    CO        True       Still Desirable     B
# 1110     6562  Denver    CO        True       Still Desirable     B
# 1111     6564  Denver    CO        True       Still Desirable     B
# 1112     6567  Denver    CO        True       Still Desirable     B
# 1113     6527  Denver    CO        True       Still Desirable     B
# 1114     6528  Denver    CO        True       Still Desirable     B
# 1115     6524  Denver    CO        True       Still Desirable     B
# 1116     6535  Denver    CO        True       Still Desirable     B
# 1117     6541  Denver    CO        True       Still Desirable     B
# 1118     6542  Denver    CO        True       Still Desirable     B
# 1119     6549  Denver    CO        True       Still Desirable     B
# 1120     6552  Denver    CO        True       Still Desirable     B
# 1121     6523  Denver    CO        True  Definitely Declining     C
# 1122     6545  Denver    CO        True  Definitely Declining     C
# 1123     6546  Denver    CO        True  Definitely Declining     C
# 1124     6544  Denver    CO        True  Definitely Declining     C
# 1125     6547  Denver    CO        True  Definitely Declining     C
# 1126     6551  Denver    CO        True  Definitely Declining     C
# 1127     6571  Denver    CO        True  Definitely Declining     C
# 1128     6561  Denver    CO        True  Definitely Declining     C
# 1129     6563  Denver    CO        True  Definitely Declining     C
# 1130     6565  Denver    CO        True  Definitely Declining     C
# 1131     6569  Denver    CO        True  Definitely Declining     C
# 1132     6530  Denver    CO        True  Definitely Declining     C
# 1133     6570  Denver    CO        True  Definitely Declining     C
# 1134     6575  Denver    CO        True  Definitely Declining     C
# 1135     6574  Denver    CO        True  Definitely Declining     C
# 1136     6534  Denver    CO        True  Definitely Declining     C
# 1137     6533  Denver    CO        True  Definitely Declining     C
# 1138     6573  Denver    CO        True  Definitely Declining     C
# 1139     6543  Denver    CO        True  Definitely Declining     C
# 1140     6539  Denver    CO        True  Definitely Declining     C
# 1141     6522  Denver    CO        True             Hazardous     D
# 1142     6568  Denver    CO        True             Hazardous     D
# 1143     6555  Denver    CO        True             Hazardous     D
# 1144     6531  Denver    CO        True             Hazardous     D
# 1145     6532  Denver    CO        True             Hazardous     D
# 1146     6557  Denver    CO        True             Hazardous     D
# 1147     6556  Denver    CO        True             Hazardous     D
# 1148     6553  Denver    CO        True             Hazardous     D
# 1149     6538  Denver    CO        True             Hazardous     D
# 1150     6548  Denver    CO        True             Hazardous     D
# 1151     6572  Denver    CO        True             Hazardous     D
# 1152     6554  Denver    CO        True             Hazardous     D
# 1153     6558  Denver    CO        True             Hazardous     D
# 1154     6559  Denver    CO        True             Hazardous     D
# 1155     6560  Denver    CO        True             Hazardous     D
# 1156     6566  Denver    CO        True             Hazardous     D
# 1157    11170  Denver    CO        True            Commercial  None
# 1158    11171  Denver    CO        True            Industrial  None
#
#            label  residentia  commercial  industrial     fill  \
# 1103          A1        True       False       False  #76a865
# 1104          A2        True       False       False  #76a865
# 1105          A3        True       False       False  #76a865
# 1106          A4        True       False       False  #76a865
# 1107          A5        True       False       False  #76a865
# 1108          A6        True       False       False  #76a865
# 1109          B1        True       False       False  #7cb5bd
# 1110         B10        True       False       False  #7cb5bd
# 1111         B11        True       False       False  #7cb5bd
# 1112         B12        True       False       False  #7cb5bd
# 1113          B2        True       False       False  #7cb5bd
# 1114          B3        True       False       False  #7cb5bd
# 1115          B4        True       False       False  #7cb5bd
# 1116          B5        True       False       False  #7cb5bd
# 1117          B6        True       False       False  #7cb5bd
# 1118          B7        True       False       False  #7cb5bd
# 1119          B8        True       False       False  #7cb5bd
# 1120          B9        True       False       False  #7cb5bd
# 1121          C1        True       False       False  #ffff00
# 1122         C10        True       False       False  #ffff00
# 1123         C11        True       False       False  #ffff00
# 1124         C12        True       False       False  #ffff00
# 1125         C13        True       False       False  #ffff00
# 1126         C14        True       False       False  #ffff00
# 1127         C15        True       False       False  #ffff00
# 1128         C16        True       False       False  #ffff00
# 1129         C17        True       False       False  #ffff00
# 1130         C18        True       False       False  #ffff00
# 1131         C19        True       False       False  #ffff00
# 1132          C2        True       False       False  #ffff00
# 1133         C20        True       False       False  #ffff00
# 1134          C3        True       False       False  #ffff00
# 1135          C4        True       False       False  #ffff00
# 1136          C5        True       False       False  #ffff00
# 1137          C6        True       False       False  #ffff00
# 1138          C7        True       False       False  #ffff00
# 1139          C8        True       False       False  #ffff00
# 1140          C9        True       False       False  #ffff00
# 1141          D1        True       False       False  #d9838d
# 1142         D10        True       False       False  #d9838d
# 1143         D11        True       False       False  #d9838d
# 1144         D12        True       False       False  #d9838d
# 1145         D13        True       False       False  #d9838d
# 1146         D14        True       False       False  #d9838d
# 1147         D15        True       False       False  #d9838d
# 1148         D16        True       False       False  #d9838d
# 1149          D2        True       False       False  #d9838d
# 1150          D3        True       False       False  #d9838d
# 1151          D4        True       False       False  #d9838d
# 1152          D5        True       False       False  #d9838d
# 1153          D6        True       False       False  #d9838d
# 1154          D7        True       False       False  #d9838d
# 1155          D8        True       False       False  #d9838d
# 1156          D9        True       False       False  #d9838d
# 1157  Commercial       False        True       False  #000000
# 1158  Industrial       False       False        True  #000000
#
#                                                geometry
# 1103  POLYGON ((-104.90814 39.74754, -104.90824 39.7...
# 1104  POLYGON ((-104.92221 39.73851, -104.92228 39.7...
# 1105  POLYGON ((-104.91281 39.72538, -104.91779 39.7...
# 1106  POLYGON ((-104.96016 39.72913, -104.96016 39.7...
# 1107  POLYGON ((-104.95956 39.72366, -104.95947 39.7...
# 1108  POLYGON ((-104.95353 39.69667, -104.95475 39.6...
# 1109  POLYGON ((-104.92811 39.74822, -104.92820 39.7...
# 1110  POLYGON ((-105.03929 39.74398, -105.03590 39.7...
# 1111  POLYGON ((-105.05265 39.76253, -105.04394 39.7...
# 1112  POLYGON ((-105.02531 39.76330, -105.02570 39.7...
# 1113  POLYGON ((-104.92811 39.74822, -104.92923 39.7...
# 1114  POLYGON ((-104.91407 39.73853, -104.91602 39.7...
# 1115  POLYGON ((-104.89870 39.73557, -104.89855 39.7...
# 1116  MULTIPOLYGON (((-104.94056 39.72683, -104.9405...
# 1117  POLYGON ((-104.94057 39.72554, -104.94063 39.7...
# 1118  POLYGON ((-104.96621 39.72905, -104.96614 39.7...
# 1119  POLYGON ((-104.95917 39.70388, -104.95912 39.7...
# 1120  POLYGON ((-104.96854 39.68571, -104.97093 39.6...
# 1121  POLYGON ((-104.88487 39.74318, -104.88489 39.7...
# 1122  MULTIPOLYGON (((-104.98040 39.68027, -104.9804...
# 1123  POLYGON ((-104.97223 39.71121, -104.98028 39.7...
# 1124  POLYGON ((-104.97330 39.70752, -104.97528 39.7...
# 1125  POLYGON ((-104.95908 39.67122, -104.95907 39.6...
# 1126  POLYGON ((-104.95910 39.67489, -104.95909 39.6...
# 1127  MULTIPOLYGON (((-104.98710 39.65292, -104.9871...
# 1128  POLYGON ((-105.02491 39.74887, -105.02494 39.7...
# 1129  POLYGON ((-105.05344 39.75303, -105.05339 39.7...
# 1130  POLYGON ((-105.02529 39.76197, -105.02524 39.7...
# 1131  POLYGON ((-105.01932 39.78569, -105.01935 39.7...
# 1132  POLYGON ((-104.94080 39.75832, -104.94081 39.7...
# 1133  POLYGON ((-105.02537 39.78752, -105.02538 39.7...
# 1134  POLYGON ((-104.95967 39.75442, -104.95964 39.7...
# 1135  POLYGON ((-104.95969 39.74389, -104.95971 39.7...
# 1136  POLYGON ((-104.94072 39.74330, -104.94082 39.7...
# 1137  POLYGON ((-104.97338 39.74474, -104.97345 39.7...
# 1138  POLYGON ((-104.95965 39.73283, -104.96405 39.7...
# 1139  POLYGON ((-104.97984 39.74005, -104.97980 39.7...
# 1140  POLYGON ((-104.94063 39.72097, -104.94065 39.7...
# 1141  POLYGON ((-104.88487 39.74318, -104.87892 39.7...
# 1142  POLYGON ((-105.00536 39.76194, -105.01126 39.7...
# 1143  POLYGON ((-104.99513 39.76131, -104.99518 39.7...
# 1144  POLYGON ((-104.96475 39.76814, -104.96472 39.7...
# 1145  POLYGON ((-104.96472 39.76440, -104.96470 39.7...
# 1146  POLYGON ((-104.97321 39.79092, -104.97324 39.7...
# 1147  POLYGON ((-104.95454 39.78368, -104.95463 39.7...
# 1148  POLYGON ((-104.95454 39.78368, -104.95464 39.7...
# 1149  POLYGON ((-104.94065 39.71942, -104.94069 39.7...
# 1150  MULTIPOLYGON (((-104.99823 39.67234, -104.9983...
# 1151  MULTIPOLYGON (((-104.99390 39.63501, -104.9971...
# 1152  POLYGON ((-105.01112 39.71752, -105.00883 39.7...
# 1153  POLYGON ((-104.98858 39.72728, -104.99153 39.7...
# 1154  POLYGON ((-105.02520 39.73579, -105.02199 39.7...
# 1155  POLYGON ((-105.02505 39.74398, -105.02378 39.7...
# 1156  POLYGON ((-105.01126 39.76195, -105.00536 39.7...
# 1157  MULTIPOLYGON (((-104.98708 39.65621, -104.9871...
# 1158  MULTIPOLYGON (((-104.99222 39.71476, -104.9921...

# %%
denver_redlining_gdf.dissolve().hvplot(
    geo=True, tiles = 'EsriImagery',
    title='Redlining in Denver, CO',
    fill_color = None, line_color= 'Blue', line_width = 2,
    width= 800
)
# Out:
# WARNING:param.GeoOverlayPlot02573: Due to internal constraints, when aspect and width/height is set, the bokeh backend uses those values as frame_width/frame_height instead. This ensures the aspect is respected, but means that the plot might be slightly larger than anticipated. Set the frame_width/frame_height explicitly to suppress this warning.
# :Overlay
#    .WMTS.I     :WMTS   [Longitude,Latitude]
#    .Polygons.I :Polygons   [Longitude,Latitude]

# %% [markdown]
# YOUR SITE DESCRIPTION HERE

# %% [markdown]
# <link rel="stylesheet" type="text/css" href="./assets/styles.css"><div class="callout callout-style-default callout-titled callout-task"><div class="callout-header"><div class="callout-icon-container"><i class="callout-icon"></i></div><div class="callout-title-container flex-fill">Try It: Store variables</div></div><div class="callout-body-container callout-body"><p>Store any variables you want for later. This should definitely
# include your un-dissolved denver redlining <code>GeoDataFrame</code> and
# your data directory path.</p></div></div>

# %%
# %store denver_redlining_gdf data_dir
# Out:
# Stored 'denver_redlining_gdf' (GeoDataFrame)
# UsageError: Unknown variable 'data_dir'
